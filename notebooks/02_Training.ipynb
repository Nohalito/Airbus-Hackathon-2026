# %% [markdown]
# # Airbus Hackatuna

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

import sys
sys.path.append('../')
sys.path.append('../src')

import config as c
import utils_N as u
import network_N as n

# Turn off warning
import warnings
warnings.filterwarnings('ignore')

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

train_ds = n.PointCloudDataset("../datasets/processed/train.h5")
val_ds = n.PointCloudDataset("../datasets/processed/val.h5")

train_loader = DataLoader(train_ds, batch_size = 8, shuffle = True)
val_loader = DataLoader(val_ds, batch_size = 8, shuffle = False)

model = n.PointNetSeg(num_classes = 4).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3)
criterion = nn.CrossEntropyLoss()

# %%
u.fit_nn(
    c.EPOCHS,
    model,
    criterion,
    optimizer,
    train_loader,
    val_loader,
    device
)
# Out:
# batch beepobed :: 100%|██████████| 70/70 [01:32<00:00,  1.32s/it]
# 		Avg train acc: 0.561783	Avg valid acc: 0.638817
#
#
# 		Avg train loss: 1.112705	Avg valid loss: 0.894868
#
# 		valid_loss decreased (inf -> 0.894868)
# 		saving model...
# batch beepobed :: 100%|██████████| 70/70 [01:32<00:00,  1.33s/it]
# 		Avg train acc: 0.587020	Avg valid acc: 0.684594
#
#
# 		Avg train loss: 1.042009	Avg valid loss: 0.912810
# batch beepobed :: 100%|██████████| 70/70 [01:32<00:00,  1.32s/it]
# 		Avg train acc: 0.608254	Avg valid acc: 0.517432
#
#
# 		Avg train loss: 0.971639	Avg valid loss: 0.896130

# %% [markdown]
# # Airbus Hackatuna

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

import sys
sys.path.append('../')
sys.path.append('../src')

import config as c
import utils_N as u
import network_N as n

# Turn off warning
import warnings
warnings.filterwarnings('ignore')

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

train_ds = n.PointCloudDataset("../datasets/processed/train.h5")
val_ds = n.PointCloudDataset("../datasets/processed/val.h5")

train_loader = DataLoader(train_ds, batch_size = 8, shuffle = True)
val_loader = DataLoader(val_ds, batch_size = 8, shuffle = False)

model = n.PointNetSeg(num_classes = 4).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3)
criterion = nn.CrossEntropyLoss()

# %%
u.fit_nn(
    c.EPOCHS,
    model,
    criterion,
    optimizer,
    train_loader,
    val_loader,
    device
)
# Out:
# batch beepobed :: 100%|██████████| 70/70 [01:30<00:00,  1.30s/it]
# 		Avg train acc: 0.510344	Avg valid acc: 0.456478
#
#
# 		Avg train loss: 1.150248	Avg valid loss: 3.379492
#
# 		valid_loss decreased (inf -> 3.379492)
# 		saving model...
# batch beepobed :: 100%|██████████| 70/70 [01:30<00:00,  1.30s/it]
# 		Avg train acc: 0.583512	Avg valid acc: 0.592213
#
#
# 		Avg train loss: 1.070352	Avg valid loss: 1.715129
#
# 		valid_loss decreased (3.379492 -> 1.715129)
# 		saving model...
# batch beepobed :: 100%|██████████| 70/70 [01:30<00:00,  1.30s/it]
# 		Avg train acc: 0.609213	Avg valid acc: 0.553873
#
#
# 		Avg train loss: 1.025419	Avg valid loss: 1.969024
# batch beepobed :: 100%|██████████| 70/70 [01:30<00:00,  1.30s/it]
# 		Avg train acc: 0.607633	Avg valid acc: 0.542441
#
#
# 		Avg train loss: 1.031156	Avg valid loss: 1.892440
# batch beepobed :: 100%|██████████| 70/70 [01:30<00:00,  1.30s/it]
# 		Avg train acc: 0.596365	Avg valid acc: 0.602795
#
#
# 		Avg train loss: 1.049839	Avg valid loss: 1.055703
#
# 		valid_loss decreased (1.715129 -> 1.055703)
# 		saving model...
